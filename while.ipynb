# %% [markdown]
# ## 7.1 函数input()的工作原理

# %%
message = input("Tell me something, and I will repeat it back to you: ")
print(message)
# Out:
# Tell me something, and I will repeat it back to you: hello, wanda
# hello, wanda

# %% [markdown]
# ### 7.1.1 编写清晰的程序

# %%
name = input("Please enter your name: ")
print("Hello, " + name + "!")
# Out:
# Please enter your name: samuel
# Hello, samuel!

# %%
prompt = "If you tell us who you are, we can personalize the messages you see."
prompt += "\nWhatever is your first name?"

name = input(prompt)
print("\nHello, " + name + "!")
# Out:
# If you tell us who you are, we can personalize the messages you see.
# Whatever is your first name?samuel
#
# Hello, samuel!

# %% [markdown]
# ### 7.1.2 使用int()来获取数值输入

# %%
age = input("How old are you?")
# Out:
# How old are you?37

# %%
age
# Out:
# '37'

# %%
age >= 37
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-56ad71d4aefc> in <module>
# ----> 1 age >= 37
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
age = input("How old are you?")
# Out:
# How old are you?37

# %%
age = int(age)

# %%
age >= 18
# Out:
# True

# %%
height = input("How tall are you, in inches?")
height = int(height)

if height >= 36:
    print("\nYou're tall enough to ride!")
else:
    print("\nYou'll be able to ride when you're a little older.")
# Out:
# How tall are you, in inches?28
#
# You'll be able to ride when you're a little older.

# %% [markdown]
# ### 7.1.3 求模运算符 %

# %%
4 % 3
# Out:
# 1

# %%
5% 3
# Out:
# 2

# %%
number = input("Enter a number, and I'll tell you if it's even or odd: ")
number = int(number)

if number % 2 == 0:
    print("\nThe number " + str(number) + " is even.")
else:
    print("\nThe number " + str(number) + " is odd.")
# Out:
# Enter a number, and I'll tell you if it's even or odd: 4
#
# The number 4 is even.

# %% [markdown]
# ### 7.1.4 在Python 2.7中获取输入raw_input()  等价Python3的 input()

# %% [markdown]
# ### 动手试一试

# %%
car_query = input("which car of type would you like?")
print("Let me see if I can find you a " + car_query.title())
# Out:
# which car of type would you like?subaru
# Let me see if I can find you a Subaru

# %%
number_meals = input("How many peoples are here for dinner tonight?")
number_meals = int(number_meals)

if number_meals >= 8:
    print("Sorry, not enough table for you!")
else:
    print("Please, follow me!")
# Out:
# How many peoples are here for dinner tonight?2
# Please, follow me!

# %%
number = input("Enter a number, I will tell you if integration of 10 or not.")
number = int(number)

if number % 10 == 0:
    print(str(number) + " is integration of 10.")
else:
    print(str(number) + " isn't integration of 10.")
# Out:
# Enter a number, I will tell you if integration of 10 or not.20
# 20 is integration of 10.

# %% [markdown]
# ## 7.2 使用while循环

# %% [markdown]
# ### 7.2.1 使用while循环

# %%
current_number = 1
while current_number <= 5:
    print(current_number)
    current_number += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### 7.2.2 让用户选择何时推出

# %%
prompt = "\nTell me something, and I will repeat it back to you:"
prompt += "\nEnter 'quit' to end the program."

message = ""
while message != 'quit':
    message = input(prompt)
    if message != 'quit':
        print(message)
# Out:
# Tell me something, and I will repeat it back to you:
# Enter 'quit' to end the program.quit

# %% [markdown]
# ### 7.2.3 使用标志

# %%
prompt = "\nTell me someting, and I will repeat it back to you:"
prompt += "\nEnter 'quit' to end the program."

active = True
while active:
    message = input(prompt)
    if message == 'quit':
        active = False
    else:
        print(message)
# Out:
# Tell me someting, and I will repeat it back to you:
# Enter 'quit' to end the program.1
# 1
#
# Tell me someting, and I will repeat it back to you:
# Enter 'quit' to end the program.2
# 2
#
# Tell me someting, and I will repeat it back to you:
# Enter 'quit' to end the program.quit

# %% [markdown]
# ### 7.2.4 使用break 退出循环

# %%
prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\n(Enter 'quit' when you are finished.)"

while True:
    city = input(prompt)
    
    if city == 'quit':
        break
    else:
        print("I'd love to go to " + city.title() + '!')
# Out:
# Please enter the name of a city you have visited:
# (Enter 'quit' when you are finished.)quit

# %% [markdown]
# ### 7.2.5 在循环中使用continue

# %%
current_number = 0 
while current_number < 10:
    current_number += 1
    if current_number % 2 == 0:
        continue
    
    print(current_number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ### 7.2.6 避免无限循环

# %%
x = 1
while x <= 5:
    print(x)
    x += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### 动手试一试

# %%
prompt = "\nPlease enter which you want pizza: 'neapolitan_pizza', 'chicago_pizza', 'sicilian_pizza'"
prompt += "\nWhen you enter 'quit' finish the orders!" 

message = ""
while message != 'quit':
    message = input(prompt)
    if message != 'quit':
         print("We will add the " + message + " in your pizza!")
# Out:
# Please enter which you want pizza: 'neapolitan_pizza', 'chicago_pizza', 'sicilian_pizza'
# When you enter 'quit' finish the orders!chicago_pizza
# We will add the chicago_pizza in your pizza!
#
# Please enter which you want pizza: 'neapolitan_pizza', 'chicago_pizza', 'sicilian_pizza'
# When you enter 'quit' finish the orders!quit

# %%
prompt = "\nThe tickets cost of rule: "
prompt += "\nAge <=3 is free"
prompt += "\n12 > Age >3, a ticket cost is $10."
prompt += "\nAge > 12, a ticket cost is $15."
prompt += "\nPlease tell us how old are you?"

# 使用条件测试来结束循环
message = ""
while message != 'quit':
    message = input(prompt)
    if message != 'quit':
        message = int(age)
        if age < 3:
            print("\nA ticket is free.")
        elif 3 < age < 12:
            print("\nA ticket is $10. ")
        elif age > 12:
            print("\nA ticket is $15.")
# Out:
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?10
#
# A ticket is $10.
#
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?quit

# %%
prompt = "\nThe tickets cost of rule: "
prompt += "\nAge <=3 is free"
prompt += "\n12 > Age >3, a ticket cost is $10."
prompt += "\nAge > 12, a ticket cost is $15."
prompt += "\nPlease tell us how old are you?"

# 使用break语句在用户输入'quit'时退出循环
while True:
    message = input(prompt)
    if message == 'quit':
        break
    else:
        message = int(age)
        if age < 3:
            print("\nA ticket is free.")
        elif 3 < age < 12:
            print("\nA ticket is $10. ")
        elif age > 12:
            print("\nA ticket is $15.")
# Out:
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?19
#
# A ticket is $10.
#
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?12
#
# A ticket is $10.
#
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?1
#
# A ticket is $10.
#
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?quit

# %%
prompt = "\nThe tickets cost of rule: "
prompt += "\nAge <=3 is free"
prompt += "\n12 > Age >3, a ticket cost is $10."
prompt += "\nAge > 12, a ticket cost is $15."
prompt += "\nPlease tell us how old are you?"

# 使用变量active 来控制循环结束的时机
active = True
while active:
    message = input(prompt)
    if message == 'quit':
        active = False
    else:
        message = int(age)
        if age < 3:
            print("\nA ticket is free.")
        elif 3 < age < 12:
            print("\nA ticket is $10. ")
        elif age > 12:
            print("\nA ticket is $15.")
# Out:
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?10
#
# A ticket is $10.
#
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?20
#
# A ticket is $10.
#
# The tickets cost of rule:
# Age <=3 is free
# 12 > Age >3, a ticket cost is $10.
# Age > 12, a ticket cost is $15.
# Please tell us how old are you?quit

# %%
x = "samuel"

message = 'wanda'
while message != 'samuel':
    print(message)
# Out:
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# wanda
# ...

# %% [markdown]
# ## 7.3 使用while循环来处理列表和字典

# %% [markdown]
# ### 7.3.1 在列表之间移动元素

# %%
# 创建一个待验证用户列表
# 和一个用于存储已验证用户的空列表
unconfirmed_users = ['alice', 'brian', 'candace']
confirmed_users = []

# 验证每个用户，直到没有验证用户为止
# 将每个经过验证的列表都移到验证用户列表中
while unconfirmed_users:
    current_user = unconfirmed_users.pop()
    print("Verifying user: " + current_user.title())
    confirmed_users.append(current_user)

# 显示所有已验证的用户
print("\nThe following users have been confirmed:")
for confirmed_user in confirmed_users:
    print(confirmed_user.title())
# Out:
# Verifying user: Candace
# Verifying user: Brian
# Verifying user: Alice
#
# The following users have been confirmed:
# Candace
# Brian
# Alice

# %% [markdown]
# ### 7.3.2 删除包含特定值得所有列表元素

# %%
pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
print(pets)

while 'cat' in pets:
    pets.remove('cat')

print(pets)
# Out:
# ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
# ['dog', 'dog', 'goldfish', 'rabbit']

# %% [markdown]
# ### 7.3.3 使用用户输入来填充字典

# %%
# 创建一个空数据集
responses = {}

# 设置一个标志，指出调查是否继续
polling_active = True
while polling_active:
    # 提示输入被调查者的名字和回答
    name = input("\nWhat is your name?")
    response = input("\nWhich mountain would you like to climb someday?")
    
    # 将答卷存储在字典中
    responses[name] = response
    
    # 看看是否还有人要参加调查
    repeat = input("Would you like to let another person respond?(yes/no)")
    if repeat == 'no':
        polling_active = False
        
# 调查结束，显示结果
print("\n--- Poll Result ---")
for name, response in responses.items():
    print(name + " would like to climb " + response + ".")
# Out:
# What is your name?samuel
#
# Which mountain would you like to climb someday?tanglang mountain
# Would you like to let another person respond?(yes/no)yes
#
# What is your name?wanda
#
# Which mountain would you like to climb someday?yangtai mountain
# Would you like to let another person respond?(yes/no)no
#
# --- Poll Result ---
# samuel would like to climb tanglang mountain.
# wanda would like to climb yangtai mountain.

# %% [markdown]
# ### 动手试一试

# %%
sandwich_orders = ['cheese sandwiches',
                   'beef sandwiches',
                   'pastrami sandwiches',
                   'tuna sandwiches',
                   'pastrami sandwiches',
                   'pork sandwiches',
                   'pastrami sandwiches',]

finished_sandwiches = []

# for sandwich_without in sandwich_orders:
#     if sandwich_without == 'pastrami sandwiches':
print("pastrami sandwiches are sales out!" )
        
while 'pastrami sandwiches' in sandwich_orders:
    sandwich_orders.remove('pastrami sandwiches')
    
while sandwich_orders:
    sandwich = sandwich_orders.pop()
    
    finished_sandwiches.append(sandwich)
for finished_sandwich in finished_sandwiches:
    print(finished_sandwich)
# Out:
# pastrami sandwiches are sales out!
# pork sandwiches
# tuna sandwiches
# beef sandwiches
# cheese sandwiches

# %%
resorts_survey = {}

active = True
while active:
    name = input("\nWhat's your name?")
    responses = input("\nIf you could visit one place in the world, where would you go?")
    
    resorts_survey[name] = responses
    
    repeat = input("Would you like to let another person respond?(yes/no) ")
    
    if repeat == 'no':
        active = False
        
    for name, resort in resorts_survey.items():
        print(str(name.title()) + ":")
        print(str(resort.title()))
# Out:
# What's your name?samuel
#
# If you could visit one place in the world, where would you go?silicon valley
# Would you like to let another person respond?(yes/no) no
# Samuel:
# Silicon Valley
